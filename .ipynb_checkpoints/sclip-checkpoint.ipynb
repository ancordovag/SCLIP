# %%
environment = "local"
if environment == "drive":
    dirname = 'drive/MyDrive/europarl/'
    from google.colab import drive
    drive.mount('/content/drive')
    # !pip install -r requirements
else:
    dirname = 'europarl/'

# %%
import torch
import torch.nn as nn
import numpy as np
import clip
from sentence_transformers import SentenceTransformer
from networks import SCLIPNN, SCLIP_LSTM, SCLIP_Attn

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)
sbert_model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# %%
#Our sentences we like to encode

train_path = 'train_sentences.txt'
test_path = 'test_sentences.txt'
valid_path = 'valid_sentences.txt'
train_filename = dirname + '/' + train_path
test_filename = dirname + '/' + test_path
valid_filename = dirname + '/' + valid_path

# %%
train_sentences = []
with open(train_filename, mode='rt', encoding='utf-8') as file_object:
    for line in file_object:
        train_sentences.append(line)
N = len(train_sentences)
print("Number of sentences : {}".format(N))
# Out:
# Number of sentences : 50

# %%
import re
regex = [r"[^A-Za-z0-9]+|[a-zA-Z][0-9]", r"(?<!\d)[0]\d*(?!\d)", r"\s+", r"[0-9]+"]
for r in regex:
    train_sentences = list(map(lambda sentence: re.sub(r, " ", sentence), train_sentences))

# %%
text = clip.tokenize(train_sentences).to(device)

# %%
with torch.no_grad():
    clip_embeddings = clip_model.encode_text(text)

# %%
with torch.no_grad():  
    sbert_embeddings = torch.from_numpy(sbert_model.encode(train_sentences))

# %%
#Print the embeddings
for sentence, clip_embedding, sbert_embedding in zip(train_sentences[:1], clip_embeddings[:1], sbert_embeddings[:1]):
    print("Sentence:", sentence)
    print("Clip Embedding: ", clip_embedding.size())
    print("Sbert Embedding: ", sbert_embedding.size())
    print("-"*10)
# Out:
# Sentence: You have requested a debate on this subject in the course of the next few days during this part session
# Clip Embedding:  torch.Size([512])
# Sbert Embedding:  torch.Size([384])
# ----------

# %%
model_NN = SCLIPNN().to(device)
model_lstm = SCLIP_LSTM().to(device)
model_attn = SCLIP_Attn().to(device)

# %%
import torch.optim as optim
models = {'NN':model_NN, 'lstm': model_lstm} #, 'attn': model_attn}
criterion = nn.MSELoss()

# %%
def train(models, epochs=150):
    all_losses = []
    for name, model in models.items():
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
        print('Training model {}'.format(name))
        losses = []
        for epoch in range(epochs):  # loop over the dataset multiple times
            epoch_loss = 0.0
            for i, data in enumerate(zip(sbert_embeddings, clip_embeddings)):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward + backward + optimize
                outputs = model(inputs)
                #print("Outputs and Labels size: {} - {}".format(outputs.size(),labels.size()))

                loss = criterion(outputs, labels)        
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()
            losses.append(epoch_loss)

            if epoch % 10 == 0:
                print("Epoch {}. Loss: {}".format(epoch, epoch_loss))
        all_losses.append(losses)
        print('Finished Training from model {}'.format(name))
        print("-"*50)
    return all_losses

# %%
losses = train(models, 100)
# Out:
# Training model NN
# Epoch 0. Loss: 12.806301236152649
# Epoch 10. Loss: 11.896541938185692
# Epoch 20. Loss: 10.755864843726158
# Epoch 30. Loss: 9.116039223968983
# Epoch 40. Loss: 6.995853424072266
# Epoch 50. Loss: 4.979973159730434
# Epoch 60. Loss: 3.6447420716285706
# Epoch 70. Loss: 2.963010463863611
# Epoch 80. Loss: 2.6417926736176014
# Epoch 90. Loss: 2.4812988452613354
# Finished Training from model NN
# --------------------------------------------------
# Training model lstm
# Epoch 0. Loss: 13.070291474461555
# Epoch 10. Loss: 12.5448437333107
# Epoch 20. Loss: 12.039266839623451
# Epoch 30. Loss: 11.548160538077354
# Epoch 40. Loss: 11.065754428505898
# Epoch 50. Loss: 10.587519258260727
# Epoch 60. Loss: 10.109996281564236
# Epoch 70. Loss: 9.630749844014645
# Epoch 80. Loss: 9.14838682860136
# Epoch 90. Loss: 8.662599921226501
# Finished Training from model lstm
# --------------------------------------------------

# %%
from matplotlib import pyplot as plt
for i, (name, model) in enumerate(models.items()):
    plt.plot(losses[i], label = name)
plt.legend()
plt.show()

# %%
test_sentences = []
with open(test_filename, mode='rt', encoding='utf-8') as file_object:
    for line in file_object:
        test_sentences.append(line)
N = len(test_sentences)
print("Number of sentences : {}".format(N))
# Out:
# Number of sentences : 50

# %%
text = clip.tokenize(test_sentences).to(device)
with torch.no_grad():
    test_clip_embeddings = clip_model.encode_text(text)

# %%
with torch.no_grad():
    test_sbert_embeddings = torch.from_numpy(sbert_model.encode(test_sentences))

# %%
def cosin_calculator(targets, predictions):
    cosines = []
    for tar, pred in zip(targets, predictions):
        cos = nn.CosineSimilarity(dim=0, eps=1e-6)
        cosine = cos(tar, pred)
        cosines.append(cosine.item())
    return np.array(cosines)

# %%
cosines = []
for name, model in models.items():
    predictions = model(test_sbert_embeddings)
    cosines.append(cosin_calculator(test_clip_embeddings, predictions))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14644\1561886936.py in <module>
#       1 cosines = []
#       2 for name, model in models.items():
# ----> 3     predictions = model(test_sbert_embeddings)
#       4     cosines.append(cosin_calculator(test_clip_embeddings, predictions))
#
# ~\PycharmProjects\SCLIP\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\PycharmProjects\SCLIP\networks.py in forward(self, x)
#      37         embedded = x.view(-1, 1, 384)
#      38         output, _ = self.lstm(embedded, (h0, c0))
# ---> 39         output = output.view(1, self.hidden_size)
#      40         logits = self.linear(output).view(self.output_size)
#      41         return logits
#
# RuntimeError: shape '[1, 100]' is invalid for input of size 5000

# %%
cosines = cosin_calculator(test_clip_embedding, predictions)
terms = []
for i, c in enumerate(cosines):
    if np_cosines.size == 0:
        break
    best_index = np.argmax(np_cosines)
    coeff = np_cosines[best_index]/(i+1)
    terms.append(coeff)
    np_cosines = np.delete(np_cosines, best_index)
mean_reciprocal_rank = sum(terms) / len(terms)
print("Mean reciprocal mean: {}".format(mean_reciprocal_rank))
# Out:
# Mean reciprocal mean: 0.04112948697314904

# %%
euclidean = torch.cdist(test_clip_embeddings, prediction_embeddings)
avg_euclidean = torch.mean(euclidean)
print("Average Euclidean: {}".format(avg_euclidean))
# Out:
# Average Euclidean: 5.139171123504639

# %%
print(test_clip_embeddings[0,:7])
print('-'*20)
print(prediction_embeddings[0,:7])
# Out:
# tensor([-0.2260, -0.3205, -0.1991, -0.3055,  0.3207,  0.2823,  0.2040])
# --------------------
# tensor([ 0.0690, -0.0512, -0.0391, -0.0413,  0.0494, -0.0264,  0.1031])

# %%
plt.plot(test_clip_embeddings[0,:100],c='r')
plt.plot(prediction_embeddings[0,:100],c='b')
plt.show()
